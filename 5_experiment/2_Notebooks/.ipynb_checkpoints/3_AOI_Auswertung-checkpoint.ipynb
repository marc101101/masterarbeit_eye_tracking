# %% [markdown]
# # Berechnung AOI Heatmaps
# ### Code zu Abschnitt 4.4

# %% [markdown]
# 1. Importieren der benötigten Bibliotheken
# 2. Definition der AOIs
# 3. Definition der Auswertefunktion
# 4. Definition zum Einlesen der Transformationsmatrizenwerte
# 5. Dateipfade einlesen (Abgabeverzeichnis 1_Daten/2_processed)
# 6. Auswertung ausführen

# %%
# Schritt 1: Importieren der benötigten Bibliotheken

import sys
import os
import pandas as pd
import numpy as np
import math
import json

from ipywidgets import interactive, IntSlider, FloatSlider
from IPython.display import display, HTML

sys.path.append('../3_Lib/py')

import matplotlib.pyplot as plt

from helper import AOI
from helper import Intersection
from helper import translate, rotate_x, rotate_y, rotate_z, scale_x, scale_y, scale_z
from helper import plot, plot_with_image, plot_vectors, plot_vectors_with_image, plot_vectors_with_image_and_aois, plot_heatmap
from helper import apply_transformation, normalize, get_all_aois_intersection, set_closest_intersection_and_get_distance, get_gaze_pairs
plt.rcParams["figure.figsize"] = (17, 5) # (w, h)

# %%
filename = "../3_Lib/cam_config.json"

matrix_cache = {
    "cam_1": None,
    "cam_2": None,
    "cam_3": None,
    "cam_4": None
}

def fill_matrix_cache():
    with open(filename, 'r') as f:
        config = json.load(f)
        matrix_cache["cam_1"] = get_transformation_matrix("cam_1", config["cam_1"])
        matrix_cache["cam_2"] = get_transformation_matrix("cam_2", config["cam_2"])
        matrix_cache["cam_3"] = get_transformation_matrix("cam_3", config["cam_3"])
        matrix_cache["cam_4"] = get_transformation_matrix("cam_4", config["cam_4"])

def get_transformation_matrix(client_id, config):     
    rot_x = rotate_x(math.radians(config["rot_x"]))
    rot_y = rotate_y(math.radians(config["rot_y"]))
    rot_z = rotate_z(math.radians(config["rot_z"]))

    s_x = scale_x(config["s_x"])
    s_y = scale_y(config["s_y"])
    s_z = scale_z(config["s_z"])

    d = translate(config["t_x"], config["t_y"], config["t_z"])
    
    return scale_x(-1) @ rotate_y(math.radians(-90)) @ d @ s_z @ s_y @ s_x @ rot_z @ rot_y @ rot_x @ scale_y(-1)


fill_matrix_cache()

# %%
# Schritt 5: Dateipfade einlesen (Abgabeverzeichnis 1_Daten/2_processed)

# siehe https://stackoverflow.com/questions/19587118/iterating-through-directories-with-python

root = '../1_Daten/2_processed'
FILE_NAMES = []

for subdir, dirs, files in os.walk(root):
    for file in files:
        if 'annotation' not in file or '.csv' not in file:
            continue
        FILE_NAMES.append(os.path.join(subdir, file).replace('\\', '/'))

# %%
def filter_data(tester, client_id, position):
    main_frame = pd.DataFrame()

    for f in FILE_NAMES:
        df = pd.read_csv(f, sep=',', engine='python')
        if(position != None):
            df = df[(df['position'] == position)]
        if(client_id != None):
            df = df[(df['client_id'] == client_id)]
        if(tester != None):
            df = df[(df['tester'] == tester)]
        main_frame = main_frame.append(df)

    return main_frame

# %%
# Schritt 3:  Definition der Auswertefunktion

def run_aoi_evaluation(aois, transformation_matrix, coordinates, gazes, heatmap_prefix, render):
    # normierte Blickrichtung auf Startkoordinaten addieren
    gaze_ends = np.swapaxes(np.swapaxes(coordinates, 0, 1) + np.swapaxes(gazes, 0, 1) * 10000, 0, 1)
    
    # transformieren
    transformed_coordinates = apply_transformation(coordinates, transformation_matrix, swap=False)
    transformed_gaze_ends = apply_transformation(gaze_ends, transformation_matrix, swap=False)

    # Blickrichtung zurückrechnen und normalisieren
    transformed_directions = transformed_gaze_ends - transformed_coordinates
    transformed_gazes = np.array([normalize(transformed_directions[i]) for i in range(len(transformed_directions))])

    # Intersektion Ojekte erstellen
    intersections = get_all_aois_intersection(transformed_coordinates, transformed_gazes, aois)

    # Kürzeste Entfernung für jeden Punkt
    distances = np.array([set_closest_intersection_and_get_distance(intersections[i]) for i in range(len(intersections))])
    
    detected_aois_with_cross_hair_dist = []
    
    for intersect in intersections:
        for single in intersect:
            if(single.is_hit):
                detected_aois_with_cross_hair_dist.append([single.aoi.title, single.dist_cross_hair_end])
                    
    # Start- und Endpunkte der Blicke (Start = Ende, wenn kein Schnittpunkt => Entfernung INF)
    gaze_starts, gaze_ends = get_gaze_pairs(transformed_coordinates, transformed_gazes, distances)
    
    gaze_starts = np.swapaxes(gaze_starts, 0, 1)
    gaze_ends = np.swapaxes(gaze_ends, 0, 1)
    
    if (render):        
        plot_vectors_with_image_and_aois(gaze_starts, gaze_ends, aois, 'Test', render)
    
    return detected_aois_with_cross_hair_dist

    #for aoi in aois:
        #plot_heatmap(aoi, aoi.title, save=True, filename='%s%s.png' % (heatmap_prefix, aoi.title))

# %%
def run_evaluation(df, client_id, position, render):
    coords = np.array([df['eye_l_X'], df['eye_l_Y'], df['eye_l_Z']])
    gazes = np.array([df['gaze_l_X'], df['gaze_l_Y'], df['gaze_l_Z']])
      
    detected_aois_with_cross_hair_dist = run_aoi_evaluation(aoi_list, matrix_cache[client_id], coords, gazes, "path", render)
    
    df = pd.DataFrame(detected_aois_with_cross_hair_dist, columns=["aoi_hits", "dist_to_cross_hair"])
    
    fig = plt.figure()
    ax1 = fig.add_subplot(121)
    ax2 = fig.add_subplot(122)
    
    df1 = df.aoi_hits.value_counts().to_frame().sort_values(by=['aoi_hits'], ascending=False)
    df2 = df.groupby('aoi_hits').mean().sort_values(by=['dist_to_cross_hair'], ascending=True)
       
    ax1 = df1.plot(kind="bar", ax=ax1)
    ax2 = df1.plot(kind="bar", ax=ax2)
    
    df1.rename(columns={'aoi_hits': client_id + "_pos_" + str(position) + "_" + "aoi_hits"}, inplace=True)
        
    display(df1)       
    display(df2)
    
    return df1

# %%
# Schritt 2:  Definition der AOIs

filename = "../3_Lib/aois.json"

aoi_list = []

def fill_aoi_list():
    with open(filename, 'r') as f:
        aois = json.load(f)
        for aoi in aois:   
            aoi_list.append(AOI(
                [aoi['aoi_x_0'], aoi['aoi_y_0'], aoi['aoi_z_0']], 
                [aoi['aoi_x_1'], aoi['aoi_y_1'], aoi['aoi_z_1']], 
                [aoi['aoi_x_2'], aoi['aoi_y_2'], aoi['aoi_z_2']], 
                [aoi['cross_hair_x'], aoi['cross_hair_y'], aoi['cross_hair_z']], 
                aoi['color'], 
                aoi['aoi_id'],
                aoi['name']))

fill_aoi_list()

# %%
main_aoi_frame = []

# %% [markdown]
# ## Evaluierung - Position 1 / cam_2

# %%
# Alle Daten aller Nutzer an Positon 1 
data = filter_data(None, "cam_2", 1)
main_aoi_frame.append(run_evaluation(data, "cam_2", 1, True));
# Out:
#                               cam_2_pos_1_aoi_hits
# Spüle                                          163
# Cerankochfeld Oben Links                       138
# Cerankochfeld Unten Links                       52
# Unterer Küchenschrank 2                         22
# Cerankochfeld Oben Rechts                       20
# Cerankochfeld Unten Rechts                      20
# Unterer Küchenschrank 3 Oben                    12
# Unterer Küchenschrank 4                          5
# Oberer Küchenschrank 5                           4
# Oberer Küchenschrank 6                           3
# Herd Zeitanzeige                                 1
#                               dist_to_cross_hair
# aoi_hits
# Herd Zeitanzeige                        5.226237
# Cerankochfeld Oben Links               21.009530
# Cerankochfeld Unten Rechts             22.904752
# Cerankochfeld Unten Links              24.841894
# Cerankochfeld Oben Rechts              26.329412
# Unterer Küchenschrank 4                58.694228
# Unterer Küchenschrank 2                80.626564
# Oberer Küchenschrank 5                 87.959476
# Oberer Küchenschrank 6                 90.505628
# Spüle                                 110.807815
# Unterer Küchenschrank 3 Oben          120.657208

# %% [markdown]
# ## Evaluierung - Position 1 / cam_3

# %%
# Alle Daten aller Nutzer an Positon 1 
data = filter_data(None, "cam_3", 1)
main_aoi_frame.append(run_evaluation(data, "cam_3", 1, True));
# Out:
#                               cam_3_pos_1_aoi_hits
# Spüle                                          263
# Cerankochfeld Oben Links                        30
# Unterer Küchenschrank 2                         20
# Cerankochfeld Oben Rechts                       13
# Cerankochfeld Unten Links                        8
# Geschirrspüler                                   6
# Unterer Küchenschrank 3 Oben                     2
# Oberer Küchenschrank 5                           2
# Cerankochfeld Unten Rechts                       1
#                               dist_to_cross_hair
# aoi_hits
# Cerankochfeld Unten Rechts             17.090929
# Cerankochfeld Oben Links               18.771552
# Cerankochfeld Unten Links              22.634325
# Cerankochfeld Oben Rechts              25.203937
# Spüle                                  73.531807
# Oberer Küchenschrank 5                 74.897121
# Unterer Küchenschrank 2                75.955244
# Geschirrspüler                         78.162466
# Unterer Küchenschrank 3 Oben          133.425481

# %% [markdown]
# ## Evaluierung - Position 2 / cam_4

# %%
# Alle Daten aller Nutzer an Positon 2 
data = filter_data(None, "cam_4", 2)
main_aoi_frame.append(run_evaluation(data, "cam_4", 2, True));
# Out:
#                         cam_4_pos_2_aoi_hits
# Spüle                                     83
# Mikrowelle                                 9
# Oberer Küchenschrank 2                     9
# Oberer Küchenschrank 3                     8
#                         dist_to_cross_hair
# aoi_hits
# Mikrowelle                       53.779359
# Spüle                            71.672065
# Oberer Küchenschrank 3           87.594045
# Oberer Küchenschrank 2          129.079932

# %% [markdown]
# ## Evaluierung - Position 3 / cam_4

# %%
# Alle Daten aller Nutzer an Positon 3 
data = filter_data(None, "cam_4", 3)
main_aoi_frame.append(run_evaluation(data, "cam_4", 3, True));
# Out:
#                                cam_4_pos_3_aoi_hits
# Spüle                                           311
# Unterer Küchenschrank 2                          67
# Geschirrspüler                                   33
# Unterer Küchenschrank 3 Mitte                    17
# Unterer Küchenschrank 1                          11
# Unterer Küchenschrank 3 Oben                      7
# Oberer Küchenschrank 2                            2
# Mikrowelle                                        2
#                                dist_to_cross_hair
# aoi_hits
# Unterer Küchenschrank 3 Mitte           46.265963
# Mikrowelle                              62.679414
# Spüle                                   64.157115
# Unterer Küchenschrank 1                 70.177106
# Unterer Küchenschrank 2                 72.962038
# Geschirrspüler                          83.906144
# Unterer Küchenschrank 3 Oben           121.794289
# Oberer Küchenschrank 2                 129.241821

# %% [markdown]
# ## Evaluierung - Position 4 / cam_4

# %%
# Alle Daten aller Nutzer an Positon 4 
data = filter_data(None, "cam_4", 4)
main_aoi_frame.append(run_evaluation(data, "cam_4", 4, True));
# Out:
#                                cam_4_pos_4_aoi_hits
# Spüle                                           418
# Unterer Küchenschrank 2                          23
# Geschirrspüler                                    4
# Unterer Küchenschrank 3 Mitte                     3
# Unterer Küchenschrank 3 Oben                      1
# Oberer Küchenschrank 2                            1
# Cerankochfeld Oben Links                          1
# Mikrowelle                                        1
# Unterer Küchenschrank 1                           1
#                                dist_to_cross_hair
# aoi_hits
# Cerankochfeld Oben Links                27.434180
# Mikrowelle                              42.629728
# Unterer Küchenschrank 3 Mitte           57.162211
# Unterer Küchenschrank 2                 67.916838
# Spüle                                   68.463998
# Unterer Küchenschrank 1                 69.042021
# Geschirrspüler                          86.940585
# Unterer Küchenschrank 3 Oben           103.800316
# Oberer Küchenschrank 2                 125.623867

# %% [markdown]
# ## Evaluierung - Position 5 / cam_1

# %%
# Alle Daten aller Nutzer an Positon 5
data = filter_data(None, "cam_1", 5)
main_aoi_frame.append(run_evaluation(data, "cam_1", 5,  True));
# Out:
#                                cam_1_pos_5_aoi_hits
# Cerankochfeld Unten Rechts                      282
# Cerankochfeld Oben Rechts                       189
# Cerankochfeld Oben Links                        140
# Cerankochfeld Unten Links                       132
# Kühlschrank                                      51
# Herd Zeitanzeige                                 24
# Unterer Küchenschrank 3 Oben                     14
# Herd                                             12
# Unterer Küchenschrank 4                           9
# Unterer Küchenschrank 3 Mitte                     3
# Herd Schalthebel 2                                3
# Spüle                                             2
# Unterer Küchenschrank 3 Unten                     1
#                                dist_to_cross_hair
# aoi_hits
# Herd Schalthebel 2                       4.933890
# Herd Zeitanzeige                        10.528605
# Cerankochfeld Oben Rechts               20.801576
# Cerankochfeld Unten Rechts              25.068480
# Cerankochfeld Oben Links                25.366080
# Cerankochfeld Unten Links               27.732787
# Unterer Küchenschrank 3 Mitte           37.663034
# Herd                                    67.955078
# Kühlschrank                             69.590877
# Unterer Küchenschrank 4                 82.463840
# Unterer Küchenschrank 3 Unten          110.676986
# Unterer Küchenschrank 3 Oben           123.471405
# Spüle                                  131.765487

# %% [markdown]
# ## AOIs Hits pro Position

# %%
test = pd.concat(main_aoi_frame, axis=1, sort=False)

display(test)

    
ax1 = test.sum().plot(kind="bar")
ax2 = test.transpose().sum().sort_values(ascending=False).to_frame()
ax2.rename(columns={0: "Treffer"}, inplace=True)

for aoi in aoi_list:
    ax2.rename(index={aoi.title: aoi.title + " - ID: " }, inplace=True)

plt.rcParams["figure.figsize"] = (17, 8) # (w, h)
ax2.plot(kind="barh")
# Out:
#                                cam_2_pos_1_aoi_hits  cam_3_pos_1_aoi_hits  \
# Spüle                                         163.0                 263.0
# Cerankochfeld Oben Links                      138.0                  30.0
# Cerankochfeld Unten Links                      52.0                   8.0
# Unterer Küchenschrank 2                        22.0                  20.0
# Cerankochfeld Oben Rechts                      20.0                  13.0
# Cerankochfeld Unten Rechts                     20.0                   1.0
# Unterer Küchenschrank 3 Oben                   12.0                   2.0
# Unterer Küchenschrank 4                         5.0                   NaN
# Oberer Küchenschrank 5                          4.0                   2.0
# Oberer Küchenschrank 6                          3.0                   NaN
# Herd Zeitanzeige                                1.0                   NaN
# Geschirrspüler                                  NaN                   6.0
# Mikrowelle                                      NaN                   NaN
# Oberer Küchenschrank 2                          NaN                   NaN
# Oberer Küchenschrank 3                          NaN                   NaN
# Unterer Küchenschrank 3 Mitte                   NaN                   NaN
# Unterer Küchenschrank 1                         NaN                   NaN
# Kühlschrank                                     NaN                   NaN
# Herd                                            NaN                   NaN
# Herd Schalthebel 2                              NaN                   NaN
# Unterer Küchenschrank 3 Unten                   NaN                   NaN
#
#                                cam_4_pos_2_aoi_hits  cam_4_pos_3_aoi_hits  \
# Spüle                                          83.0                 311.0
# Cerankochfeld Oben Links                        NaN                   NaN
# Cerankochfeld Unten Links                       NaN                   NaN
# Unterer Küchenschrank 2                         NaN                  67.0
# Cerankochfeld Oben Rechts                       NaN                   NaN
# Cerankochfeld Unten Rechts                      NaN                   NaN
# Unterer Küchenschrank 3 Oben                    NaN                   7.0
# Unterer Küchenschrank 4                         NaN                   NaN
# Oberer Küchenschrank 5                          NaN                   NaN
# Oberer Küchenschrank 6                          NaN                   NaN
# Herd Zeitanzeige                                NaN                   NaN
# Geschirrspüler                                  NaN                  33.0
# Mikrowelle                                      9.0                   2.0
# Oberer Küchenschrank 2                          9.0                   2.0
# Oberer Küchenschrank 3                          8.0                   NaN
# Unterer Küchenschrank 3 Mitte                   NaN                  17.0
# Unterer Küchenschrank 1                         NaN                  11.0
# Kühlschrank                                     NaN                   NaN
# Herd                                            NaN                   NaN
# Herd Schalthebel 2                              NaN                   NaN
# Unterer Küchenschrank 3 Unten                   NaN                   NaN
#
#                                cam_4_pos_4_aoi_hits  cam_1_pos_5_aoi_hits
# Spüle                                         418.0                   2.0
# Cerankochfeld Oben Links                        1.0                 140.0
# Cerankochfeld Unten Links                       NaN                 132.0
# Unterer Küchenschrank 2                        23.0                   NaN
# Cerankochfeld Oben Rechts                       NaN                 189.0
# Cerankochfeld Unten Rechts                      NaN                 282.0
# Unterer Küchenschrank 3 Oben                    1.0                  14.0
# Unterer Küchenschrank 4                         NaN                   9.0
# Oberer Küchenschrank 5                          NaN                   NaN
# Oberer Küchenschrank 6                          NaN                   NaN
# Herd Zeitanzeige                                NaN                  24.0
# Geschirrspüler                                  4.0                   NaN
# Mikrowelle                                      1.0                   NaN
# Oberer Küchenschrank 2                          1.0                   NaN
# Oberer Küchenschrank 3                          NaN                   NaN
# Unterer Küchenschrank 3 Mitte                   3.0                   3.0
# Unterer Küchenschrank 1                         1.0                   NaN
# Kühlschrank                                     NaN                  51.0
# Herd                                            NaN                  12.0
# Herd Schalthebel 2                              NaN                   3.0
# Unterer Küchenschrank 3 Unten                   NaN                   1.0
